# %%
## Import data set 
import pandas as pd
data = pd.read_csv(r"D:\Net flix\Netflix - Copy.csv")
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
## Head 
## tail 
## Shape
data.head()
data.tail()
data.shape
# Out:
# (7789, 11)

# %%
## data size number of elements
data.size
# Out:
# 85679

# %%
## Columns only
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
## Data types
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
## Info 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
## Find duplicate record and remove duplicate records
## Duplicate record 
data[data.duplicated()] ## 2 duplicate record
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
## Remove duplicates 
data.drop_duplicates(inplace = True) ## Present data after removing duplicates

# %%
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
## Find Null value in data 
data.isnull() ## True present Null value
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
## Find number of Null values presnt 
data.isnull().sum() ## number of Null value according to columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
## present null values by heatmaps
import seaborn as sns 
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
## For "HOPUSe of card" and who is director 
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
## Str.contains()

data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Highest number of TV shows and Movies were released

# %%
## Search data type of "Date"
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
##To_ Datetime

data['Date_N']=pd.to_datetime(data['Release_Date'])

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # Dt.year.value count()

# %%
data['Date_N'].dt.year.value_counts() ## It count oucarence of indivisual year in date column 

Syntex dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N']=pd.to_datetime(data['Release_Date'])
data['Date_N'].dt.year.value_counts().plot(kind ='bar')
# Out:
# <Axes: >

# %% [markdown]
# # How many Movies and TV shows are in the dataset

# %%
## GROUPBY () Function

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
import seaborn as sns
sns.displot(data["Category"], color = "green", kde=True)
plt.show()

# %% [markdown]
# # Show all movies realesed in 2020

# %%
## Cretaing new column of Year 

data['Year'] = data['Date_N'].dt.year
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
## filter data by MOVIE & 2020 ofv difrent column 
Movie_2020=data[(data['Category']=='Movie') & (data['Year']==2020)] 
Movie_2020
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# # Only show Title of all TV SHows that released in INDIA

# %%
data[ (data['Category']== 'TV Show') & (data['Country']=='India') ]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Show Top 10 director who gaves highest number of TV Shows & Movies to Netflix

# %%
## call dataset 
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
## use value-count( ) function
data['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Sam Dunn                   1
# Name: Director, Length: 4050, dtype: int64

# %%
## For Top 10
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# # Show all records of category = Movies and Type = Comedies or Country = United Kingdom

# %% [markdown]
# ## Fillter AND, OR Operators

# %%
M_C_UK =data[(data['Category']=='Movie')&(data['Type']=='Comedies')
            |(data['Country']=='United Kingdom')]
M_C_UK.head(10)
# Out:
#     Show_Id Category                        Title                Director  \
# 19      s20    Movie                          '89                     NaN
# 33      s34    Movie                 #realityhigh        Fernando Lebrija
# 58      s59  TV Show                  100% Hotter                     NaN
# 72      s73    Movie                     17 Again             Burr Steers
# 82      s83    Movie          2036 Origin Unknown           Hasraf Dulull
# 84      s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 85      s86  TV Show                     21 Again                     NaN
# 93      s94    Movie            27: Gone Too Soon       Simon Napier-Bell
# 148    s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174    s175    Movie  A Futile and Stupid Gesture              David Wain
#
#                                                   Cast               Country  \
# ...

# %% [markdown]
# # How many movies / Shows, Tom Cruise was cast?

# %%
## Filter 
data[data['Cast']=='Tom Cruise']
## It is showing "o" Result because of Null values in this rows
## Multiple eleiements in column is the reason for not filteration
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data[data['Cast'].str.contains('Tom Cruise')]

## It is showing errors due to NUll values
## Need to eleminate Null values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     133         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %% [markdown]
# ## Creating data frame with out null values

# %%
## Using Dropna( ) function for elemination
new_data = data.dropna()

# %%
new_data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
## Now find out
new_data[new_data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # What are diffrent rating define by Netflix

# %% [markdown]
# ## nunique()

# %%
new_data['Rating'].nunique()
## 14 is unique charecter in Rating column
# Out:
# 14

# %% [markdown]
# ## Unique() function to present unique character

# %%
new_data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # How many Movies got 'TV-14' in Canada

# %%
new_data[(new_data['Category']=='Movie')&(new_data['Rating']== 'TV-14')
         &(new_data['Country']=='Canada')].shape
# Out:
# (9, 13)

# %% [markdown]
# # How many TV Shows gor the 'R' rating, after year 2018?

# %%
## TV Shows + R + after 2018

data[(data['Category']== 'TV Show')&(data['Rating']== 'R')&(data['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
## Number of count()

data[(data['Category']== 'TV Show')&(data['Rating']== 'R')&(data['Year']>2018)].shape
# Out:
# (1, 13)

# %% [markdown]
# # What is maximum duration of movie/show of netflix

# %%
## Duration coloumn has contained diffrent character
## where "str.split()" would be use

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## str.split()

# %%
data[['Minutes', 'Units']]= data['Duration'].str.split(' ', expand= True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes    Units
# 0       4  Seasons
# 1      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# # Which indivisual country has height number of TV Shows

# %%
## Creating new data set

TV_shows = data[(data['Category']== 'TV Show')]
TV_shows.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes    Units
# 0       4  Seasons
# 5       1   Season

# %%
## Calcualte Hightes number of TV shows
Hg_country = TV_shows.Country.value_counts().head(1)

Hg_country
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # How can sort data set by "Year"

# %%
## Using sort_value() function 

import pandas as pd
data = pd.read_csv(r"D:\Net flix\Netflix - Copy.csv")
data['Date_N']=pd.to_datetime(data['Release_Date'])
data['Year'] = data['Date_N'].dt.year
data.sort_values(by = 'Year', ascending =False).head(10)
# Out:
#      Show_Id Category               Title                      Director  \
# 7353   s7352    Movie             Unknown            Jaume Collet-Serra
# 2013   s2014    Movie    Enter the Dragon                 Robert Clouse
# 2349   s2350    Movie           Gangaajal                   Prakash Jha
# 1497   s1498    Movie      Cool Hand Luke              Stuart Rosenberg
# 1194   s1195    Movie   Can't Hardly Wait  Harry Elfont, Deborah Kaplan
# 104     s105    Movie  30 Minutes or Less               Ruben Fleischer
# 692     s693    Movie      Bad Grandpa .5                 Jeff Tremaine
# 5139   s5139    Movie          Redemption                 Steven Knight
# 3521   s3522    Movie              Lagaan            Ashutosh Gowariker
# 5521   s5521    Movie  Sex and the City 2          Michael Patrick King
#
#                                                    Cast  \
# 7353  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# ...

# %% [markdown]
# ## Find all the instances where:
# ## Category is "Movie" & "Dramas"
# ## OR
# ## Category is TV show & Kids TV

# %%
M_D_T_K = data[(data['Category']== 'Movie') & (data['Type'] == 'Drama') 
| (data['Category']== 'TV Show') & (data['Type'] == "Kids' TV")]
M_D_T_K.head
M_D_T_K.reset_index(drop = True)

## Using of " " for ("Kids' TV") beacuse its already contain (  ' ) in character
# Out:
#     Show_Id Category              Title             Director  \
# 0      s112  TV Show            44 Cats                  NaN
# 1      s277  TV Show       Abby Hatcher          Kyran Kelly
# 2      s435  TV Show        Alphablocks                  NaN
# 3      s599  TV Show  Ask the StoryBots                  NaN
# 4      s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ..      ...      ...                ...                  ...
# 200   s7667  TV Show      World of Winx       Iginio Straffi
# 201   s7716  TV Show               Yoko                  NaN
# 202   s7718  TV Show                YOM                  NaN
# 203   s7757  TV Show                 Z4                  NaN
# 204   s7760  TV Show          Zak Storm                  NaN
#
#                                                   Cast  \
# 0    Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 1    Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 2      Teresa Gallagher, David Holt, Lizzie Waterworth
# ...

# %% [markdown]
# # Find TV shows and Movies are get TV-MA & PG ?

# %%
## Using of regex function to find out

# %%
data.groupby('Rating').Rating.count()
# Out:
# Rating
# G             39
# NC-17          3
# NR            84
# PG           247
# PG-13        386
# R            665
# TV-14       1931
# TV-G         194
# TV-MA       2865
# TV-PG        806
# TV-Y         280
# TV-Y7        271
# TV-Y7-FV       6
# UR             5
# Name: Rating, dtype: int64

# %%
## Using of Regex function 
import re
r = clean_data.loc[clean_data['Rating'].str.contains("R|TV-MA", flags=re.I, regex = True)]
r
# Out:
#      Show_Id Category           Title                               Director  \
# 1         s2    Movie           07:19                      Jorge Michel Grau
# 2         s3    Movie           23:59                           Gilbert Chan
# 5         s6  TV Show              46                            Serdar Akar
# 6         s7    Movie             122                        Yasir Al Yasiri
# 7         s8    Movie             187                         Kevin Reynolds
# ...      ...      ...             ...                                    ...
# 7775   s7774    Movie  Zoé: Panoramas  Rodrigo Guardiola, Gabriel Cruz Rivas
# 7776   s7775    Movie          Zodiac                          David Fincher
# 7780   s7779    Movie      Zombieland                        Ruben Fleischer
# 7782   s7781    Movie             Zoo                           Shlok Sharma
# 7784   s7783    Movie            Zozo                            Josef Fares
#
# ...

# %%
Presenation of TV Shows and Movies

# %%
sns.scatterplot(x="Year", y="Rating", data = clean_data, hue = 'Category'
                , color = 'Year', palette='rocket_r')
plt.show()

# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"D:\Net flix\Netflix - Copy.csv")
sns.displot(data["Category"], color = "green")
plt.show()

# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"D:\Net flix\Netflix - Copy.csv")
data['Date_N']=pd.to_datetime(data['Release_Date'])
data['Year'] = data['Date_N'].dt.year
data.sort_values(by = 'Year', ascending =False)
sns.lineplot(x="Year", y="Rating", data = data)
plt.show()

# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"D:\Net flix\Netflix - Copy.csv")
data1 = data.value_counts('Rating')
data1.plot()
# Out:
# <Axes: xlabel='Rating'>
